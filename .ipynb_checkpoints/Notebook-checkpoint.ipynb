# %% [markdown]
# ### Setting up GPU memory growth to avoid OOM errors

# %%
import tensorflow as tf

# avoid oom errors by setting GPU memory growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.set_logical_device_configuration(gpu, [tf.config.LogicalDeviceConfiguration(memory_limit=2048)])

# %% [markdown]
# ### Define Hyperparameter

# %%
learning_rate = .003
meta_step_size = .25

inner_batch_size = 25
eval_batch_size = 25

meta_iters = 2000
eval_iters = 5
inner_iters = 4

eval_interval = 1
train_shots = 20
shots = 5
classes = 10

# %% [markdown]
# ### Data Loader

# %%
class DataLoader:
    def __init__(self, training):
        split = 'train' if training else 'test'
        ds = tfds.load('mnist', split=split, as_supervised=True, shuffle_files=False)
        self.data = {}
        
        def extract(image, label):
            image = tf.image.convert_image_dtype(image, tf.float32) # normalized image
            image = tf.image.resize(image, [28,28])
            return image, label
        
        for image, label in ds.map(extract):
            image = image.numpy()
            label = str(label.numpy())
            if label not in self.data:
                self.data[label] = []
            self.data[label].append(image)
        self.labels = list(self.data.keys())
    
    def get_mini_dataset(self, batch_size, repetitions, shots, classes, split=False):
        temp_labels = np.zeros(shape=(classes * shots))
        temp_images = np.zeros(shape=(classes * shots, 28, 28, 1))
        if split:
            test_labels = np.zeros(shape=(classes))
            test_images = np.zeros(shape=(classes, 28, 28, 1))
        
        # get random subset from entire label set
        label_subset = random.choices(self.labels, k=classes)
        for i, label in enumerate(label_subset):
            # use enumerated value as temporary label for mini-batch
            temp_labels[i * shots: (i + 1) * shots] = i
            if split:
                test_labels[i] = i
                images_to_split = random.choices(self.data[label_subset[i]], k=shots + 1)
                test_images[i] = images_to_split[-1]
                temp_images[i * shots : (i + 1) * shots] = images_to_split[:-1]
            else:
                temp_images[i * shots : (i + 1) * shots] = random.choices(self.data[label_subset[i]], k=shots)
        
        dataset = tf.data.Dataset.from_tensor_slices(
            (temp_images.astype(np.float32), temp_labels.astype(np.int32))
        )
        dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)
        if split:
            return dataset, test_images, test_labels
        return dataset

# %%
import urllib3
import tensorflow_datasets as tfds
import numpy as np

urllib3.disable_warnings()  # Disable SSL warnings that may happen during download.
train_dataset = DataLoader(training=True)
test_dataset = DataLoader(training=False)

# %% [markdown]
# ### Visualize Dataset Example

# %%
from matplotlib import pyplot as plt

_, axs = plt.subplots(5, 5, figsize=(20,20))
sample_keys = list(train_dataset.data.keys())

for i in range(5):
    for j in range(5):
        temp_image = train_dataset.data[sample_keys[i]][j]
        temp_image = np.stack((temp_image[:,:,0],) * 3, axis=2)
        temp_image *= 255
        temp_image = np.clip(temp_image, 0, 255).astype('uint8')
        if j == 2:
            axs[i,j].set_title('Label: {}'.format(sample_keys[i]))
        axs[i,j].imshow(temp_image, cmap='gray')
        axs[i,j].xaxis.set_visible(False)
        axs[i,j].yaxis.set_visible(False)
plt.tight_layout()
plt.show()

# %%
from keras import layers
from keras import Model
from tensorflow.keras.optimizers import SGD

with tf.device('/GPU:0'):
    inputs = layers.Input(shape=(28,28,1))

    # block 1
    conv1_1 = layers.Conv2D(16, (3,3), padding='same', activation='relu')(inputs)
    conv1_2 = layers.Conv2D(16, (3,3), padding='same', activation='relu')(conv1_1)
    pool1 = layers.MaxPooling2D((2,2))(conv1_2)

    # block 2 
    conv2_1 = layers.Conv2D(32, (5,5), padding='same', activation='relu')(pool1)
    conv2_2 = layers.Conv2D(32, (5,5), padding='same', activation='relu')(conv2_1)
    pool2 = layers.MaxPooling2D((2,2))(conv2_2)

    # block 3
    conv3_1 = layers.Conv2D(32, (5,5), padding='same', activation='relu')(pool2)
    conv3_2 = layers.Conv2D(32, (5,5), padding='same', activation='relu')(conv3_1)
    pool3 = layers.MaxPooling2D((2,2))(conv3_2)

    # skip connection
    flatten1 = layers.Flatten()(pool1)
    flatten2 = layers.Flatten()(pool2)
    flatten3 = layers.Flatten()(pool3)

    concat = layers.concatenate([flatten1, flatten2, flatten3])

    fc1 = layers.Dense(128, activation='relu')(concat)
    do1 = layers.Dropout(.2)(fc1)

    fc2 = layers.Dense(64, activation='relu')(do1)
    do2 = layers.Dropout(.2)(fc2)
    outputs = layers.Dense(10, activation='softmax')(do2)

    model = Model(inputs, outputs)
    model.compile()
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 16)   160         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 16)   2320        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 14, 14, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 32)   12832       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 32)   25632       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 32)    0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 32)     25632       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 32)     25632       ['conv2d_4[0][0]']
#
# ...

# %%
from keras.utils import plot_model

plot_model(model, show_layer_activations=True)

# %% [markdown]
# ### Model Training

# %%
from tensorflow import keras
from IPython.display import clear_output
import random

training, testing = [], []
for meta_iter in range(meta_iters):
    frac_done = meta_iter / meta_iters
    cur_meta_step_size = (1 - frac_done) * meta_step_size
    
    # temporary save model weights
    old_vars = model.get_weights()
    
    # get sample from dataset
    mini_dataset = train_dataset.get_mini_dataset(
        inner_batch_size, inner_iters, train_shots, classes
    )
    
    for images, labels in mini_dataset:
        with tf.GradientTape() as tape:
            preds = model(images)
            loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
        grads = tape.gradient(loss, model.trainable_weights)
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
    new_vars = model.get_weights()
    
    # perform SGD for meta step
    for var in range(len(new_vars)):
        new_vars[var] = old_vars[var] + ((new_vars[var] - old_vars[var]) * cur_meta_step_size)
    model.set_weights(new_vars)
    
    # eval loop
    if meta_iter & eval_interval == 0:
        accuracies = []
        for dataset in (train_dataset, test_dataset):
            train_set, test_images, test_labels = dataset.get_mini_dataset(
                eval_batch_size, eval_iters, shots, classes, split=True
            )
            old_vars = model.get_weights()
            
            # train on sample
            for images, labels in train_set:
                with tf.GradientTape() as tape:
                    preds = model(images)
                    loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
                grads = tape.gradient(loss, model.trainable_weights)
                optimizer.apply_gradients(zip(grads, model.trainable_weights))
            test_preds = model.predict(test_images)
            test_preds = tf.argmax(test_preds).numpy()
            num_correct = (test_preds == test_labels).sum()
            model.set_weights(old_vars)
            accuracies.append(num_correct / classes)
        training.append(accuracies[0])
        testing.append(accuracies[1])
        if meta_iter % 20 == 0:
            clear_output(wait=True)
            print('Batch %d: train = %f, test = %f' % (meta_iter, accuracies[0], accuracies[1]))
# Out:
# Batch 1980: train = 0.500000, test = 1.000000
# ...
# 1/1 [==============================] - 0s 21ms/step

# %%
train_set, test_images, test_labels = dataset.get_mini_dataset(
    eval_batch_size, eval_iters, shots, classes, split=True
)

for images, labels in train_set:
    with tf.GradientTape() as tape:
        preds = model(images)
        loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
    grads = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
test_preds = model.predict(test_images)
test_preds = tf.argmax(test_preds).numpy()

_, axs = plt.subplots(1,5, figsize=(20,8))
sample_keys = list(train_dataset.data.keys())

for i, ax in zip(range(5), axs):
    temp_image = np.stack((test_images[i,:,:,0],) * 3, axis=2)
    temp_image *= 255
    temp_image = np.clip(temp_image, 0, 255).astype('uint8')
    ax.set_title('Label: {}, Prediction: {}'.format(int(test_labels[i]), test_preds[i]))
    ax.imshow(temp_image, cmap="gray")
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
